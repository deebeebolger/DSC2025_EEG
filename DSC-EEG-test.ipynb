# %% [markdown]
# ## Notebook to test your Jupyter Notebook and MNE-Python installation.
#
# Ideally, try to run this script locally, on your computer, in your IDE of choice before the TD on 21 Marche to ensure that your installation ofd MNE-Python functions.
#
# <div class = "alert alert-block alert-info">
# <b>Note the following :</b>
#
# - The "Data" folder with the data should be in same repertoire as your scripts.
# - Make sure that each *.set file has an accompanying *.fdt file.
# - For this test script you will need to load the following dataset:
# - When you visualise the EEG, test if you can scroll through the data using the cursor on the bottom (time) and the cursor on the vertical axis (electrode).
# - The figure should open in a separate window.
#
# </div>

# %%
#%matplotlib widget        # This should allow you to interact with the figures that you plot using plt.

import mne
import matplotlib.pyplot as plt
import numpy as np
import os

fname = 'sub-001_eeg_sub-001_task-med2_eeg_short.set'
filepath = 'Data'
fullpath = os.path.join(filepath, fname)                  # Define the path to the data.
rawIn = mne.io.read_raw_eeglab(fullpath, preload=True)    # Load in the raw data into an object called rawIn.
mne.viz.plot_raw(rawIn, duration= 5.0, n_channels=20, remove_dc=True)
# Out:
# Reading /Users/bolger/Desktop/TD-DSC-2025/scripts_data/Data/sub-001_eeg_sub-001_task-med2_eeg_short.fdt
# Reading 0 ... 51200  =      0.000 ...    50.000 secs...
# /var/folders/60/tv1lj_b10zq7ypz5s1kvq4_cr3bc6f/T/ipykernel_36290/539875298.py:11: RuntimeWarning: Unknown types found, setting as type EEG:
# ppg: ['Plet']
# temp: ['Temp']
#   rawIn = mne.io.read_raw_eeglab(fullpath, preload=True)    # Load in the raw data into an object called rawIn.
# /var/folders/60/tv1lj_b10zq7ypz5s1kvq4_cr3bc6f/T/ipykernel_36290/539875298.py:11: RuntimeWarning: Limited 2 annotation(s) that were expanding outside the data range.
#   rawIn = mne.io.read_raw_eeglab(fullpath, preload=True)    # Load in the raw data into an object called rawIn.
# /var/folders/60/tv1lj_b10zq7ypz5s1kvq4_cr3bc6f/T/ipykernel_36290/539875298.py:11: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
# ...
